# %% [markdown]
# # M7: Assignment l Clustering with K-Means and DBSCAN

# %% [markdown]
# Kaggle dataset: https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks

# %%
# Importing necessary  libraires 
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
# Creating DataFrame
# The goodreads.csv file had a couple of columns that were not correctly separated by a comma so used on_bad_lines to get rid of a couple of rows. 
good_reads_df = pd.read_csv("goodreads.csv", on_bad_lines = "skip")

# %%
# Taking a look at the counts it looks like on_bad_lines got rid of 5 rows.
good_reads_df.count()
# Out:
# bookID                11123
# title                 11123
# authors               11123
# average_rating        11123
# isbn                  11123
# isbn13                11123
# language_code         11123
#   num_pages           11123
# ratings_count         11123
# text_reviews_count    11123
# publication_date      11123
# publisher             11123
# dtype: int64

# %%
# Displaying first few rows.
good_reads_df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
# Checking for null values 
good_reads_df.isna().sum()
# no null values
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
#   num_pages           0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %% [markdown]
# We can see that text_reviews and ratings_count features both have some rows with big differences in numbers.

# %%
# The number of unique authors is 6639 this is not fully unique because there are some authors that appear multiple times because of them co-writing with others.
author_value_counts = good_reads_df.authors.unique().value_counts().sum()
author_value_counts

good_reads_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  str
#  2   authors             11123 non-null  str
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  str
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  str
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  str
#  11  publisher           11123 non-null  str
# dtypes: float64(1), int64(5), str(6)
# memory usage: 1.0 MB

# %%
good_reads_df["num_pages"] = good_reads_df["  num_pages"]

# %%
# Visualizing average ratings with histplot
plt.hist(good_reads_df['average_rating'], bins=20)
plt.show()

# %% [markdown]
# Looks like our dataset has many values that are within 4 to 4.5 stars.

# %%
# Create scatter plot to see how  average rating aginst number of pages.
plt.scatter(x='num_pages', y='average_rating', data=good_reads_df)
plt.show()

# %% [markdown]
# It looks like most books in the dataset have  about less than 2,500 pages

# %% [markdown]
# ### K-means

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import OneHotEncoder

# %%
good_reads_to_encode = good_reads_df[["title", "authors", "isbn","language_code","publication_date","publisher"]]

# %%
books_encoder = OneHotEncoder()
good_reads_1hot = pd.get_dummies(good_reads_df, drop_first=True)

# %%
good_reads_1hot
# Out:
#        bookID  average_rating         isbn13    num_pages  ratings_count  \
# 0           1            4.57  9780439785969          652        2095690
# 1           2            4.49  9780439358071          870        2153167
# 2           4            4.42  9780439554893          352           6333
# 3           5            4.56  9780439655484          435        2339585
# 4           8            4.78  9780439682589         2690          41428
# ...       ...             ...            ...          ...            ...
# 11118   45631            4.06  9781560254416          512            156
# 11119   45633            4.08  9780140110876          635            783
# 11120   45634            3.96  9780140131963          415            820
# 11121   45639            3.72  9780060878825          434            769
# 11122   45641            3.91  9788497646987          272            113
#
#        text_reviews_count  num_pages  \
# 0                   27591        652
# 1                   29221        870
# 2                     244        352
# 3                   36325        435
# 4                     164       2690
# ...                   ...        ...
# 11118                  20        512
# 11119                  56        635
# 11120                  95        415
# 11121                 139        434
# 11122                  12        272
#
#        title_$30 Film School: How to Write  Direct  Produce  Shoot  Edit  Distribute  Tour With  and Sell Your Own No-Budget Digital Movie  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 11118                                              False
# 11119                                              False
# 11120                                              False
# 11121                                              False
# 11122                                              False
#
#        title_'Salem's Lot  title_1 000 Places to See Before You Die  ...  \
# 0                   False                                     False  ...
# 1                   False                                     False  ...
# 2                   False                                     False  ...
# 3                   False                                     False  ...
# 4                   False                                     False  ...
# ...                   ...                                       ...  ...
# 11118               False                                     False  ...
# 11119               False                                     False  ...
# 11120               False                                     False  ...
# 11121               False                                     False  ...
# 11122               False                                     False  ...
#
#        publisher_小学館  publisher_小学館 [Shōgakukan]  publisher_時報出版  \
# 0              False                        False           False
# 1              False                        False           False
# 2              False                        False           False
# 3              False                        False           False
# 4              False                        False           False
# ...              ...                          ...             ...
# 11118          False                        False           False
# 11119          False                        False           False
# 11120          False                        False           False
# 11121          False                        False           False
# 11122          False                        False           False
#
#        publisher_東立  publisher_皇冠文化出版有限公司  publisher_聯經出版事業股份有限公司  \
# 0             False                 False                   False
# 1             False                 False                   False
# 2             False                 False                   False
# 3             False                 False                   False
# 4             False                 False                   False
# ...             ...                   ...                     ...
# 11118         False                 False                   False
# 11119         False                 False                   False
# 11120         False                 False                   False
# 11121         False                 False                   False
# 11122         False                 False                   False
#
#        publisher_英文漢聲出版股份有限公司  publisher_角川書店 (Kadokawa Shoten)  \
# 0                       False                             False
# 1                       False                             False
# 2                       False                             False
# 3                       False                             False
# 4                       False                             False
# ...                       ...                               ...
# 11118                   False                             False
# 11119                   False                             False
# 11120                   False                             False
# 11121                   False                             False
# 11122                   False                             False
#
#        publisher_講談社  publisher_集英社
# 0              False          False
# 1              False          False
# 2              False          False
# 3              False          False
# 4              False          False
# ...              ...            ...
# 11118          False          False
# 11119          False          False
# 11120          False          False
# 11121          False          False
# 11122          False          False
#
# [11123 rows x 34107 columns]

# %%
# good_reads_num = good_reads_df[i for i in good_reads_df.columns]
numeric_df = []
for i in good_reads_df.columns:
    if good_reads_df[i].dtype == "int":
        numeric_df.append(i)
numeric_df = good_reads_df[numeric_df]

# %%
good_reads_1hot = pd.concat([numeric_df, good_reads_1hot], axis=1)
good_reads_1hot
# Out:
#        bookID         isbn13    num_pages  ratings_count  text_reviews_count  \
# 0           1  9780439785969          652        2095690               27591
# 1           2  9780439358071          870        2153167               29221
# 2           4  9780439554893          352           6333                 244
# 3           5  9780439655484          435        2339585               36325
# 4           8  9780439682589         2690          41428                 164
# ...       ...            ...          ...            ...                 ...
# 11118   45631  9781560254416          512            156                  20
# 11119   45633  9780140110876          635            783                  56
# 11120   45634  9780140131963          415            820                  95
# 11121   45639  9780060878825          434            769                 139
# 11122   45641  9788497646987          272            113                  12
#
#        num_pages  bookID  average_rating         isbn13    num_pages  ...  \
# 0            652       1            4.57  9780439785969          652  ...
# 1            870       2            4.49  9780439358071          870  ...
# 2            352       4            4.42  9780439554893          352  ...
# 3            435       5            4.56  9780439655484          435  ...
# 4           2690       8            4.78  9780439682589         2690  ...
# ...          ...     ...             ...            ...          ...  ...
# 11118        512   45631            4.06  9781560254416          512  ...
# 11119        635   45633            4.08  9780140110876          635  ...
# 11120        415   45634            3.96  9780140131963          415  ...
# 11121        434   45639            3.72  9780060878825          434  ...
# 11122        272   45641            3.91  9788497646987          272  ...
#
#        publisher_小学館  publisher_小学館 [Shōgakukan]  publisher_時報出版  \
# 0              False                        False           False
# 1              False                        False           False
# 2              False                        False           False
# 3              False                        False           False
# 4              False                        False           False
# ...              ...                          ...             ...
# 11118          False                        False           False
# 11119          False                        False           False
# 11120          False                        False           False
# 11121          False                        False           False
# 11122          False                        False           False
#
#        publisher_東立  publisher_皇冠文化出版有限公司  publisher_聯經出版事業股份有限公司  \
# 0             False                 False                   False
# 1             False                 False                   False
# 2             False                 False                   False
# 3             False                 False                   False
# 4             False                 False                   False
# ...             ...                   ...                     ...
# 11118         False                 False                   False
# 11119         False                 False                   False
# 11120         False                 False                   False
# 11121         False                 False                   False
# 11122         False                 False                   False
#
#        publisher_英文漢聲出版股份有限公司  publisher_角川書店 (Kadokawa Shoten)  \
# 0                       False                             False
# 1                       False                             False
# 2                       False                             False
# 3                       False                             False
# 4                       False                             False
# ...                       ...                               ...
# 11118                   False                             False
# 11119                   False                             False
# 11120                   False                             False
# 11121                   False                             False
# 11122                   False                             False
#
#        publisher_講談社  publisher_集英社
# 0              False          False
# 1              False          False
# 2              False          False
# 3              False          False
# 4              False          False
# ...              ...            ...
# 11118          False          False
# 11119          False          False
# 11120          False          False
# 11121          False          False
# 11122          False          False
#
# [11123 rows x 34113 columns]

# %%
scaler = StandardScaler()
good_reads_df_scaled = scaler.fit_transform(good_reads_1hot)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
y_pred = kmeans.fit_predict(good_reads_df_scaled)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(11123,), dtype=int32)

# %%
kmeans.cluster_centers_
# Out:
# array([[-5.73464189e-04, -5.10309288e-05,  3.58995708e-04, ...,
#          1.44834217e-05,  2.50905349e-05,  3.54929541e-05],
#        [ 5.30980050e-01,  4.72503875e-02, -3.32400110e-01, ...,
#         -1.34104415e-02, -2.32317445e-02, -3.28635178e-02]],
#       shape=(2, 34113))

# %%
from sklearn.decomposition import PCA

# %%
X = good_reads_df_scaled[:,0]

# %%
good_reads_df_scaled[:,1]
# Out:
# array([0.04641441, 0.04641344, 0.04641389, ..., 0.04573792, 0.045559  ,
#        0.06460552], shape=(11123,))

# %%
plt.scatter(good_reads_df_scaled[:,0],good_reads_df_scaled[:,1])
plt.show()

# %%
pca = PCA(n_components=2)

# 2. Transform the WHOLE scaled matrix, not just two columns
X_pca = pca.fit_transform(good_reads_df_scaled)

# 3. Plot the result (X_pca[:, 0] vs X_pca[:, 1])
plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred, cmap='viridis', alpha=0.5)
plt.title("PCA")
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.show()

# %% [markdown]
# DBSCAN

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(min_samples=3, eps=0.5)

# %%
clusters = dbscan.fit_predict(good_reads_df_scaled)
clusters
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], shape=(11123,))

# %%
plt.scatter(good_reads_df_scaled[:, 0], good_reads_df_scaled[:, 1], c=clusters)
plt.show()
